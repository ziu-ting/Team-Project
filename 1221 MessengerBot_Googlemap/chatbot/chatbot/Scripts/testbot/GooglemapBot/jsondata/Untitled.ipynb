# %%
#google搜尋

import webbrowser

str='台北車站'
url='https://www.google.com/search?q='
webbrowser.open_new_tab(url+str)
# Out:
# True

# %%
#刪除冗詞

dict={'location':["去","往哪","哪","位置","地址","地點","方向","怎麼走","走"],
    'toilet':["廁所","尿","大便","拉屎","屎","撇條","排遺","排泄","便便","便所","化妝室","洗手間"],
    "toolong":["你","我","他","想","要","請問","的","是","有","嗎","在","裡","怎麼","如何","沒有","哩","勒","呢","啊","能","食物","很","真","可以","方式","資訊","不","給","甚麼","什麼","那","多少","一下"],
    "營業時間":["營業時間","幾點關門","幾點","入場","關門","時間","開始","開放"],
    "電話":["電話","專線","幾號","號碼","手機","連絡","聯絡"],
    "介紹":["簡介","特色","高度","長度","多高","多長","歷史","介紹","內容","文化","活動","官網","網站","資訊","限時","外送","附近"],
    "價錢":["價格","票價","多少錢","錢","貴","便宜","花費","費用","花"],
    "wifi":["wifi","WIFI","網路","上網","無線"],
    "菜單":["菜單","餐點","低消","飲料","葷","素","蛋奶素"],
    "評價":["評價","好吃","好玩","有趣"],
    "福利":["插座","充電","電源","電"],
    "乘車":["搭乘","搭","車子","公車","捷運","站","到","多久","多少時間"]}
str="可以介紹一下北車嗎"
a=0
a2=0
a3=0
a4=0
a5=0
a6=0
a7=0
a8=0
a9=0
a10=0
a11=0
chr=0
toolong=0
ans=0
a=len(dict["toilet"])
a2=len(dict["location"])
a3=len(dict["營業時間"])
a4=len(dict["電話"])
a5=len(dict["介紹"])
a6=len(dict["wifi"])
a7=len(dict["菜單"])
a8=len(dict["評價"])
a9=len(dict["福利"])
a10=len(dict["乘車"])
a11=len(dict["價錢"])
toolong=len(dict["toolong"])

for h in range(toolong):
    if str.find(dict["toolong"][h])>=0 :
        dle = str.find(dict["toolong"][h])
        dle_long=len(dict["toolong"][h])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
for i in range(a):
    if str.find(dict["toilet"][i])>=0 and ans<=0:
        print("您附近的廁所有以下這些")
        ans=ans+1
for i10 in range(a10):
    if str.find(dict["乘車"][i10])>=0 and ans<=0:
        dle = str.find(dict["乘車"][i10])
        dle_long=len(dict["乘車"][i10])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print("以下是"+str+"的交通資訊")
        ans=ans+1
for i11 in range(a11):
    if str.find(dict["價錢"][i11])>=0 and ans<=0:
        dle = str.find(dict["價錢"][i11])
        dle_long=len(dict["價錢"][i11])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print("以下是"+str+"的價錢資訊")
        ans=ans+1
for i2 in range(a2):
    if str.find(dict["location"][i2])>=0 and ans<=0:
        dle = str.find(dict["location"][i2])
        dle_long=len(dict["location"][i2])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print("這是"+str+"的詳細位置")
        print("https://www.google.com.tw/maps/search/"+str)
        ans=ans+1
for i3 in range(a3):
    if str.find(dict["營業時間"][i3])>=0 and ans<=0:
        dle = str.find(dict["營業時間"][i3])
        dle_long=len(dict["營業時間"][i3])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print(str,"的營業時間是")
        ans=ans+1
for i4 in range(a4):
    if str.find(dict["電話"][i4])>=0 and ans<=0:
        dle = str.find(dict["電話"][i4])
        dle_long=len(dict["電話"][i4])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print(str,"的電話是")
        ans=ans+1
for i5 in range(a5):
    if str.find(dict["介紹"][i5])>=0 and ans<=0:
        dle = str.find(dict["介紹"][i5])
        dle_long=len(dict["介紹"][i5])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print("以下是"+str+"的相關資訊")
        ans=ans+1
for i6 in range(a6):
    if str.find(dict["wifi"][i6])>=0 and ans<=0:
        dle = str.find(dict["wifi"][i6])
        dle_long=len(dict["wifi"][i6])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print("以下是"+str+"的wifi資訊")
        ans=ans+1
        
for i7 in range(a7):
    if str.find(dict["菜單"][i7])>=0 and ans<=0:
        dle = str.find(dict["菜單"][i7])
        dle_long=len(dict["菜單"][i7])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print("以下是"+str+"的菜單資訊")
        ans=ans+1
for i8 in range(a8):
    if str.find(dict["評價"][i8])>=0 and ans<=0:
        dle = str.find(dict["評價"][i8])
        dle_long=len(dict["評價"][i8])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print("以下是"+str+"的評價資訊")
        ans=ans+1
for i9 in range(a9):
    if str.find(dict["福利"][i9])>=0 and ans<=0:
        dle = str.find(dict["福利"][i9])
        dle_long=len(dict["福利"][i9])
        dle2=dle+dle_long
        str=str[:dle]+str[dle2:]
        print("以下是"+str+"的福利資訊")
        ans=ans+1

        
print(str)

#貴族世家 北車 去XX要多久 飲料貴嗎
# Out:
# 以下是北車的相關資訊
# 北車

# %%
#結巴測試

dict={'location':["去","往哪","哪","位置","地址","地點","方向","怎麼走","走"]}

import sys 
sys.path.append('C:\Python34\Lib\site-packages')
import jieba
import jieba.posseg

string = "桃園到台北很遠嗎?"
seg = jieba.posseg.cut(string)

j = []
x = 0
n1 = []
for i in seg:
    j.append((i.word, i.flag))
for element in j:
    #print(element[0],element[1])
    if element[1] == 'ns' or element[1] == 'n':
        x += 1;
        if x == 1:
            n1 = element[0];
        if x > 1:
            print(element[0]+"和"+n1+"是地名")
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\哲宇\AppData\Local\Temp\jieba.cache
# Loading model cost 0.990 seconds.
# Prefix dict has been built succesfully.
# 台北和桃園是地名

# %%
#應用json檔
import json
with open('toilet.json', 'r', encoding="utf-8") as f:
    data = json.load(f)

mylocation = '臺中市'
a = len(data)
for i in range(a):
    if data[i]['Country'] == mylocation:
        print(data[i]['Country'],data[i]['City'],data[i]['Village'],data[i]['Name'],data[i]['Address'],data[i]['Administration'])
# Out:
# 臺中市 和平區 梨山里 梨山文物陳列館(館內)-殘廁 臺中市和平區福壽路14號 參山國家風景區管理處
# 臺中市 和平區 梨山里 梨山文物陳列館(館內)-女廁 臺中市和平區福壽路14號 參山國家風景區管理處
# 臺中市 和平區 梨山里 梨山文物陳列館(館內)-男廁 臺中市和平區福壽路14號 參山國家風景區管理處
# 臺中市 和平區 梨山里 梨山文物陳列館-殘廁 臺中市和平區福壽路14號 參山國家風景區管理處
# 臺中市 和平區 梨山里 梨山文物陳列館-女廁 臺中市和平區福壽路14號 參山國家風景區管理處
# 臺中市 和平區 梨山里 梨山文物陳列館-男廁 臺中市和平區福壽路14號 參山國家風景區管理處
# 臺中市 和平區 梨山里 梨山遊客中心-女廁 臺中市和平區梨山里中正路95號 參山國家風景區管理處
